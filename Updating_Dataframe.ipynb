# %%
import pandas

# %%
df1 = pandas.read_csv("C:/Users/user/Desktop/DMX/Datasets/Additional Datasets/Clustering  Ex 2 .csv")
df1
# Out:
#    Symbol                                Name  Market_Cap  Beta  PE_Ratio  \
# 0     NVS                         Novartis AG       96.65  0.19      21.6
# 1     BAY                            Bayer AG       16.90  1.11      27.9
# 2    CHTT                        Chattem, Inc        0.41  0.85      26.0
# 3     AVE                             Aventis       47.16  0.32      20.1
# 4     IVX                    IVAX Corporation        2.60  0.65      19.9
# 5     PFE                          Pfizer Inc      199.47  0.65      23.6
# 6     AZN                     AstraZeneca PLC       67.63  0.52      21.5
# 7     JNJ                   Johnson & Johnson      173.93  0.46      28.4
# 8     ABT                 Abbott Laboratories       68.44  0.32      24.7
# 9     BMY        Bristol-Myers Squibb Company       51.33  0.50      13.9
# 10    SGP         Schering-Plough Corporation       34.10  0.51      18.9
# 11    AGN                      Allergan, Inc.        7.58  0.41      82.5
# ...

# %%
df2 = df1.set_index('Symbol')
df2
# Out:
#                                       Name  Market_Cap  Beta  PE_Ratio   ROE  \
# Symbol
# NVS                            Novartis AG       96.65  0.19      21.6  17.9
# BAY                               Bayer AG       16.90  1.11      27.9   3.9
# CHTT                          Chattem, Inc        0.41  0.85      26.0  24.1
# AVE                                Aventis       47.16  0.32      20.1  21.8
# IVX                       IVAX Corporation        2.60  0.65      19.9  21.4
# PFE                             Pfizer Inc      199.47  0.65      23.6  45.6
# AZN                        AstraZeneca PLC       67.63  0.52      21.5  27.4
# JNJ                      Johnson & Johnson      173.93  0.46      28.4  28.6
# ABT                    Abbott Laboratories       68.44  0.32      24.7  26.4
# BMY           Bristol-Myers Squibb Company       51.33  0.50      13.9  34.8
# SGP            Schering-Plough Corporation       34.10  0.51      18.9  22.6
# ...

# %%
df3 = df2.drop(df2.columns[10:11],1)
df3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11940\1900756084.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df3 = df2.drop(df2.columns[10:11],1)
#                                       Name  Market_Cap  Beta  PE_Ratio   ROE  \
# Symbol
# NVS                            Novartis AG       96.65  0.19      21.6  17.9
# BAY                               Bayer AG       16.90  1.11      27.9   3.9
# CHTT                          Chattem, Inc        0.41  0.85      26.0  24.1
# AVE                                Aventis       47.16  0.32      20.1  21.8
# IVX                       IVAX Corporation        2.60  0.65      19.9  21.4
# PFE                             Pfizer Inc      199.47  0.65      23.6  45.6
# AZN                        AstraZeneca PLC       67.63  0.52      21.5  27.4
# JNJ                      Johnson & Johnson      173.93  0.46      28.4  28.6
# ...

# %%
df4 = df3.drop(df3.columns[11:12],1)
df4
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11940\1031144946.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df4 = df3.drop(df3.columns[11:12],1)
#                                       Name  Market_Cap  Beta  PE_Ratio   ROE  \
# Symbol
# NVS                            Novartis AG       96.65  0.19      21.6  17.9
# BAY                               Bayer AG       16.90  1.11      27.9   3.9
# CHTT                          Chattem, Inc        0.41  0.85      26.0  24.1
# AVE                                Aventis       47.16  0.32      20.1  21.8
# IVX                       IVAX Corporation        2.60  0.65      19.9  21.4
# PFE                             Pfizer Inc      199.47  0.65      23.6  45.6
# AZN                        AstraZeneca PLC       67.63  0.52      21.5  27.4
# JNJ                      Johnson & Johnson      173.93  0.46      28.4  28.6
# ...

# %%
df5 = df4.drop('Name',1)
df5.head(5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11940\42449282.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df5 = df4.drop('Name',1)
#         Market_Cap  Beta  PE_Ratio   ROE   ROA  Asset_Turnover  Leverage  \
# Symbol
# NVS          96.65  0.19      21.6  17.9  11.2             0.5      0.06
# BAY          16.90  1.11      27.9   3.9   1.4             0.6      0.00
# CHTT          0.41  0.85      26.0  24.1   4.3             0.6      3.51
# AVE          47.16  0.32      20.1  21.8   7.5             0.6      0.34
# IVX           2.60  0.65      19.9  21.4   6.8             0.6      1.45
#
#         Rev_Growth  Net_Profit_Margin     Location
# Symbol
# NVS          -2.69               22.4  SWITZERLAND
# BAY          -3.17                2.6      GERMANY
# CHTT          6.38                7.5           US
# AVE          26.81               12.9       FRANCE
# ...

# %%
df5.shape[0] #number of rows
# Out:
# 21

# %% [markdown]
# # Adding and Updating Columns

# %%
df5['Continent'] = df5.shape[0] * ['Europe/America']

# %%
df5.head(10)
# Out:
#         Market_Cap  Beta  PE_Ratio   ROE   ROA  Asset_Turnover  Leverage  \
# Symbol
# NVS          96.65  0.19      21.6  17.9  11.2             0.5      0.06
# BAY          16.90  1.11      27.9   3.9   1.4             0.6      0.00
# CHTT          0.41  0.85      26.0  24.1   4.3             0.6      3.51
# AVE          47.16  0.32      20.1  21.8   7.5             0.6      0.34
# IVX           2.60  0.65      19.9  21.4   6.8             0.6      1.45
# PFE         199.47  0.65      23.6  45.6  19.2             0.8      0.16
# AZN          67.63  0.52      21.5  27.4  15.4             0.9      0.00
# JNJ         173.93  0.46      28.4  28.6  16.3             0.9      0.10
# ABT          68.44  0.32      24.7  26.4  11.8             0.7      0.42
# BMY          51.33  0.50      13.9  34.8  15.1             0.9      0.57
#
#         Rev_Growth  Net_Profit_Margin     Location       Continent
# Symbol
# NVS          -2.69               22.4  SWITZERLAND  Europe/America
# ...

# %%
df5['Continent'] = df5['Location'] + ', ' + 'Europe/America' 
df5.head(5)
# Out:
#         Market_Cap  Beta  PE_Ratio   ROE   ROA  Asset_Turnover  Leverage  \
# Symbol
# NVS          96.65  0.19      21.6  17.9  11.2             0.5      0.06
# BAY          16.90  1.11      27.9   3.9   1.4             0.6      0.00
# CHTT          0.41  0.85      26.0  24.1   4.3             0.6      3.51
# AVE          47.16  0.32      20.1  21.8   7.5             0.6      0.34
# IVX           2.60  0.65      19.9  21.4   6.8             0.6      1.45
#
#         Rev_Growth  Net_Profit_Margin     Location  \
# Symbol
# NVS          -2.69               22.4  SWITZERLAND
# BAY          -3.17                2.6      GERMANY
# CHTT          6.38                7.5           US
# AVE          26.81               12.9       FRANCE
# IVX          13.99               11.0           US
#
#                           Continent
# Symbol
# NVS     SWITZERLAND, Europe/America
# BAY         GERMANY, Europe/America
# CHTT             US, Europe/America
# AVE          FRANCE, Europe/America
# ...

# %% [markdown]
# # Adding Rows

# %%
df5_t = df5.T

# %%
df5_t
# Out:
# Symbol                                     NVS                      BAY  \
# Market_Cap                               96.65                     16.9
# Beta                                      0.19                     1.11
# PE_Ratio                                  21.6                     27.9
# ROE                                       17.9                      3.9
# ROA                                       11.2                      1.4
# Asset_Turnover                             0.5                      0.6
# Leverage                                  0.06                      0.0
# Rev_Growth                               -2.69                    -3.17
# Net_Profit_Margin                         22.4                      2.6
# Location                           SWITZERLAND                  GERMANY
# Continent          SWITZERLAND, Europe/America  GERMANY, Europe/America
#
# Symbol                           CHTT                     AVE  \
# ...

# %%
df5_t['PHX'] = [45.7, 0.55, 19.2, 18.5, 8.9, 0.4, 0.34, 15.12, 18.8, 'Nigeria', 'Africa']
df5_t['EMZ'] = [67.7, 6.55, 23.2, 20.5, 10.9, 0.9, 0.97, 18.12, 20.8, 'Nigeria', 'Africa']

# %%
df5 = df5_t.T
df5
# Out:
#        Market_Cap  Beta PE_Ratio   ROE   ROA Asset_Turnover Leverage  \
# Symbol
# NVS         96.65  0.19     21.6  17.9  11.2            0.5     0.06
# BAY          16.9  1.11     27.9   3.9   1.4            0.6      0.0
# CHTT         0.41  0.85     26.0  24.1   4.3            0.6     3.51
# AVE         47.16  0.32     20.1  21.8   7.5            0.6     0.34
# IVX           2.6  0.65     19.9  21.4   6.8            0.6     1.45
# PFE        199.47  0.65     23.6  45.6  19.2            0.8     0.16
# AZN         67.63  0.52     21.5  27.4  15.4            0.9      0.0
# JNJ        173.93  0.46     28.4  28.6  16.3            0.9      0.1
# ABT         68.44  0.32     24.7  26.4  11.8            0.7     0.42
# BMY         51.33   0.5     13.9  34.8  15.1            0.9     0.57
# SGP          34.1  0.51     18.9  22.6  13.3            0.8      0.0
# AGN          7.58  0.41     82.5  12.9   5.5            0.9      0.6
# ...
